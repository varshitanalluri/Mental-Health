# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = "Children_Dataset.csv"  
df = pd.read_csv(file_path)

# %%
print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 20 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Name                                                                           9000 non-null   object
#  1   Email                                                                          9000 non-null   object
#  2   Age                                                                            9000 non-null   int64
#  3   Feeling nervous, anxious or on edge                                            9000 non-null   object
#  4   Not being able to stop or control worrying                                     9000 non-null   object
#  5   Worrying too much about different things                                       9000 non-null   object
#  6   Trouble relaxing                                                               9000 non-null   object
#  7   Being so restless that it is hard to sit still                                 9000 non-null   object
#  8   Becoming easily annoyed or irritable                                           9000 non-null   object
#  9   Feeling afraid as if something awful might happen                              9000 non-null   object
#  10  Feeling tired or having little energy                                          9000 non-null   object
#  11  Poor appetite or overeating                                                    9000 non-null   object
#  12  Feeling bad about yourself—or that you are a failure                           9000 non-null   object
#  13  Trouble concentrating on things                                                9000 non-null   object
#  14  Moving or speaking so slowly that other people could have noticed              9000 non-null   object
#  15  Thoughts that you would be better off dead or of hurting yourself in some way  9000 non-null   object
#  16  Anxiety_Score                                                                  9000 non-null   int64
#  17  Stress_Score                                                                   9000 non-null   int64
#  18  Anxiety_Level                                                                  9000 non-null   object
#  19  Stress_Level                                                                   9000 non-null   object
# dtypes: int64(3), object(17)
# memory usage: 1.4+ MB
# None

# %%
print("\nFirst 5 Rows:")
df.head()
# Out:
# First 5 Rows:
#               Name                    Email  Age  \
# 0   Richard Herman    amywalker@example.org   21
# 1        John Park    lindsey60@example.org   17
# 2        Roy Allen   brittany63@example.org   17
# 3  Donna Henderson  jorgeharris@example.com   19
# 4     Mason Carter       jnunez@example.net   20
#
#   Feeling nervous, anxious or on edge  \
# 0                        Several days
# 1                          Not at all
# 2                          Not at all
# 3                    Nearly every day
# 4                        Several days
#
#   Not being able to stop or control worrying  \
# 0                                 Not at all
# 1                               Several days
# 2                                 Not at all
# 3                                 Not at all
# 4                    More than half the days
#
#   Worrying too much about different things Trouble relaxing  \
# 0                  More than half the days       Not at all
# 1                             Several days     Several days
# 2                         Nearly every day       Not at all
# 3                               Not at all     Several days
# 4                             Several days       Not at all
#
#   Being so restless that it is hard to sit still  \
# 0                                     Not at all
# 1                                     Not at all
# 2                                   Several days
# 3                                   Several days
# 4                                     Not at all
#
#   Becoming easily annoyed or irritable  \
# 0                           Not at all
# 1                           Not at all
# 2                           Not at all
# 3                           Not at all
# 4                           Not at all
#
#   Feeling afraid as if something awful might happen  \
# 0                                        Not at all
# 1                                        Not at all
# 2                                        Not at all
# 3                                        Not at all
# 4                                        Not at all
#
#   Feeling tired or having little energy Poor appetite or overeating  \
# 0                      Nearly every day            Nearly every day
# 1                      Nearly every day                  Not at all
# 2                          Several days            Nearly every day
# 3               More than half the days            Nearly every day
# 4                          Several days                  Not at all
#
#   Feeling bad about yourself—or that you are a failure  \
# 0                                         Not at all
# 1                                         Not at all
# 2                                         Not at all
# 3                                         Not at all
# 4                            More than half the days
#
#   Trouble concentrating on things  \
# 0                    Several days
# 1                      Not at all
# 2                Nearly every day
# 3         More than half the days
# 4                Nearly every day
#
#   Moving or speaking so slowly that other people could have noticed  \
# 0                                   Nearly every day
# 1                                         Not at all
# 2                                   Nearly every day
# 3                            More than half the days
# 4                                   Nearly every day
#
#   Thoughts that you would be better off dead or of hurting yourself in some way  \
# 0                            More than half the days
# 1                            More than half the days
# 2                            More than half the days
# 3                                         Not at all
# 4                                       Several days
#
#    Anxiety_Score  Stress_Score Anxiety_Level Stress_Level
# 0              3             2           Low          Low
# 1              3             1           Low          Low
# 2              4             1           Low          Low
# 3              5             0           Low          Low
# 4              4             2           Low          Low

# %%
print("\nSummary Statistics:")
df.describe(include='all')
# Out:
# Summary Statistics:
#                  Name               Email          Age  \
# count            9000                9000  9000.000000
# unique           8513                8809          NaN
# top     Michael Smith  osmith@example.com          NaN
# freq                7                   3          NaN
# mean              NaN                 NaN    18.993000
# std               NaN                 NaN     1.418394
# min               NaN                 NaN    17.000000
# 25%               NaN                 NaN    18.000000
# 50%               NaN                 NaN    19.000000
# 75%               NaN                 NaN    20.000000
# max               NaN                 NaN    21.000000
#
#        Feeling nervous, anxious or on edge  \
# count                                 9000
# unique                                   4
# top                             Not at all
# freq                                  3505
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#        Not being able to stop or control worrying  \
# count                                        9000
# unique                                          4
# top                                    Not at all
# freq                                         3510
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#        Worrying too much about different things Trouble relaxing  \
# count                                      9000             9000
# unique                                        4                4
# top                                  Not at all       Not at all
# freq                                       3518             3436
# mean                                        NaN              NaN
# std                                         NaN              NaN
# min                                         NaN              NaN
# 25%                                         NaN              NaN
# 50%                                         NaN              NaN
# 75%                                         NaN              NaN
# max                                         NaN              NaN
#
#        Being so restless that it is hard to sit still  \
# count                                            9000
# unique                                              4
# top                                        Not at all
# freq                                             3396
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#        Becoming easily annoyed or irritable  \
# count                                  9000
# unique                                    4
# top                              Not at all
# freq                                   3470
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#        Feeling afraid as if something awful might happen  \
# count                                               9000
# unique                                                 4
# top                                           Not at all
# freq                                                3433
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        Feeling tired or having little energy Poor appetite or overeating  \
# count                                   9000                        9000
# unique                                     4                           4
# top                         Nearly every day            Nearly every day
# freq                                    2302                        2328
# mean                                     NaN                         NaN
# std                                      NaN                         NaN
# min                                      NaN                         NaN
# 25%                                      NaN                         NaN
# 50%                                      NaN                         NaN
# 75%                                      NaN                         NaN
# max                                      NaN                         NaN
#
#        Feeling bad about yourself—or that you are a failure  \
# count                                                9000
# unique                                                  4
# top                                      Nearly every day
# freq                                                 2304
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Trouble concentrating on things  \
# count                             9000
# unique                               4
# top                         Not at all
# freq                              2274
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#        Moving or speaking so slowly that other people could have noticed  \
# count                                                9000
# unique                                                  4
# top                               More than half the days
# freq                                                 2278
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Thoughts that you would be better off dead or of hurting yourself in some way  \
# count                                                9000
# unique                                                  4
# top                                      Nearly every day
# freq                                                 2277
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Anxiety_Score  Stress_Score Anxiety_Level Stress_Level
# count     9000.000000   9000.000000          9000         9000
# unique            NaN           NaN             3            3
# top               NaN           NaN           Low          Low
# freq              NaN           NaN          3000         3000
# mean         8.814000      8.829000           NaN          NaN
# std          5.907336      5.960065           NaN          NaN
# min          0.000000      0.000000           NaN          NaN
# 25%          4.000000      4.000000           NaN          NaN
# 50%          8.000000      8.000000           NaN          NaN
# 75%         13.000000     13.000000           NaN          NaN
# max         21.000000     21.000000           NaN          NaN

# %%
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# Name                                                                             0
# Email                                                                            0
# Age                                                                              0
# Feeling nervous, anxious or on edge                                              0
# Not being able to stop or control worrying                                       0
# Worrying too much about different things                                         0
# Trouble relaxing                                                                 0
# Being so restless that it is hard to sit still                                   0
# Becoming easily annoyed or irritable                                             0
# Feeling afraid as if something awful might happen                                0
# Feeling tired or having little energy                                            0
# Poor appetite or overeating                                                      0
# Feeling bad about yourself—or that you are a failure                             0
# Trouble concentrating on things                                                  0
# Moving or speaking so slowly that other people could have noticed                0
# Thoughts that you would be better off dead or of hurting yourself in some way    0
# Anxiety_Score                                                                    0
# Stress_Score                                                                     0
# Anxiety_Level                                                                    0
# Stress_Level                                                                     0
# dtype: int64

# %%
df = df.drop(columns=["Name", "Email", "Age", "Anxiety_Score", "Stress_Score"])

# %%
response_mapping = {
    "Not at all": 0,
    "Several days": 1,
    "More than half the days": 2,
    "Nearly every day": 3
}

for col in df.columns[:-2]:
    df[col] = df[col].map(response_mapping)

# %%
label_encoder = LabelEncoder()
df["Anxiety_Level"] = label_encoder.fit_transform(df["Anxiety_Level"])
df["Stress_Level"] = label_encoder.fit_transform(df["Stress_Level"])

# %%
X = df.drop(columns=["Anxiety_Level", "Stress_Level"])
y_anxiety = df["Anxiety_Level"]
y_stress = df["Stress_Level"]

# %%
X = X.fillna(X.mode().iloc[0])

# %%
X_train, X_test, y_anxiety_train, y_anxiety_test = train_test_split(X, y_anxiety, test_size=0.2, random_state=42)
X_train, X_test, y_stress_train, y_stress_test = train_test_split(X, y_stress, test_size=0.2, random_state=42)

# %%
models = {
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier()
}

best_anxiety_model = None
best_stress_model = None
best_anxiety_acc = 0
best_stress_acc = 0

print("\nEvaluating Models...\n")
for name, model in models.items():
    model.fit(X_train, y_anxiety_train)
    y_anxiety_pred = model.predict(X_test)
    anxiety_acc = accuracy_score(y_anxiety_test, y_anxiety_pred)

    model.fit(X_train, y_stress_train)
    y_stress_pred = model.predict(X_test)
    stress_acc = accuracy_score(y_stress_test, y_stress_pred)

    print(f"{name} Anxiety Accuracy: {anxiety_acc:.2f}")
    print(f"{name} Stress Accuracy: {stress_acc:.2f}")
    print("-" * 40)

    if anxiety_acc > best_anxiety_acc:
        best_anxiety_acc = anxiety_acc
        best_anxiety_model = model

    if stress_acc > best_stress_acc:
        best_stress_acc = stress_acc
        best_stress_model = model

print(f"\nBest Model for Anxiety: {best_anxiety_model} with {best_anxiety_acc:.2f} accuracy")
print(f"Best Model for Stress: {best_stress_model} with {best_stress_acc:.2f} accuracy")
# Out:
# Evaluating Models...
#
# Random Forest Anxiety Accuracy: 0.95
# Random Forest Stress Accuracy: 0.95
# ----------------------------------------
# Decision Tree Anxiety Accuracy: 0.87
# Decision Tree Stress Accuracy: 0.88
# ----------------------------------------
# SVM Anxiety Accuracy: 0.99
# SVM Stress Accuracy: 0.99
# ----------------------------------------
# KNN Anxiety Accuracy: 0.91
# KNN Stress Accuracy: 0.91
# ----------------------------------------
#
# Best Model for Anxiety: SVC() with 0.99 accuracy
# Best Model for Stress: SVC() with 0.99 accuracy

# %%
print("Please answer the following questions using:")
print("0 - Not at all")
print("1 - Several days")
print("2 - More than half the days")
print("3 - Nearly every day\n")

user_input = []
for question in X.columns:
    while True:
        try:
            ans = int(input(f"{question.replace('_', ' ')}: "))
            if ans in [0, 1, 2, 3]:
                user_input.append(ans)
                break
            else:
                print("Please enter a number between 0 and 3.")
        except ValueError:
            print("Invalid input. Please enter a number.")

user_df = pd.DataFrame([user_input], columns=X.columns)

predicted_anxiety = best_anxiety_model.predict(user_df)[0]
predicted_stress = best_stress_model.predict(user_df)[0]

reverse_label = dict(enumerate(label_encoder.classes_))

print("\n--- Prediction Results ---")
print(f"Anxiety Level: {reverse_label[predicted_anxiety]}")
print(f"Stress Level: {reverse_label[predicted_stress]}")
# Out:
# Please answer the following questions using:
# 0 - Not at all
# 1 - Several days
# 2 - More than half the days
# 3 - Nearly every day
#
# Feeling nervous, anxious or on edge: 1
# Not being able to stop or control worrying: 0
# Worrying too much about different things: 0
# Trouble relaxing: 0
# Being so restless that it is hard to sit still: 0
# Becoming easily annoyed or irritable: 0
# Feeling afraid as if something awful might happen: 1
# Feeling tired or having little energy: 0
# Poor appetite or overeating: 0
# Feeling bad about yourself—or that you are a failure: 0
# Trouble concentrating on things: 0
# Moving or speaking so slowly that other people could have noticed: 0
# Thoughts that you would be better off dead or of hurting yourself in some way: 0
#
# --- Prediction Results ---
# Anxiety Level: Low
# Stress Level: Low
